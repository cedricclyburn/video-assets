# %%
# Install necessary packages
# !pip install -q --progress-bar off llama-index-core llama-index-readers-docling \
llama-index-node-parser-docling llama-index-embeddings-huggingface \
llama-index-llms-huggingface-api llama-index-vector-stores-milvus \
llama-index-readers-file python-dotenv

# %%
# Import Modules & Define Helper Functions
import os
from pathlib import Path
from tempfile import mkdtemp
from warnings import filterwarnings
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Suppress warnings for cleaner outputs
filterwarnings(action="ignore", category=UserWarning, module="pydantic")
filterwarnings(action="ignore", category=FutureWarning, module="easyocr")

# Prevent tokenizer parallelism issues
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# Function to get environment variables
def _get_env_from_colab_or_os(key):
    return os.getenv(key)

# %%
# Define Main Parameters
import os
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI

# Fetch HuggingFace token from environment variables
hf_token = os.getenv("HF_TOKEN")

# Ensure the token is set
if not hf_token:
    raise EnvironmentError("HF_TOKEN environment variable is not set!")

# Define embedding and generation models
EMBED_MODEL = HuggingFaceEmbedding(model_name="BAAI/bge-small-en-v1.5")
MILVUS_URI = str(Path(mkdtemp()) / "docling.db")
GEN_MODEL = HuggingFaceInferenceAPI(
    token=hf_token,
    model_name="mistralai/Mixtral-8x7B-Instruct-v0.1",
)

SOURCE = "https://arxiv.org/pdf/2408.09869"  # Docling Technical Report
QUERY = "Which are the main AI models in Docling?"

embed_dim = len(EMBED_MODEL.get_text_embedding("hi"))

# %%
# Define RAG Pipeline with DoclingReader
from llama_index.core import StorageContext, VectorStoreIndex
from llama_index.core.node_parser import MarkdownNodeParser
from llama_index.readers.docling import DoclingReader
from llama_index.vector_stores.milvus import MilvusVectorStore

# Define the DoclingReader and node parser
reader = DoclingReader()
node_parser = MarkdownNodeParser()

# Configure the vector store
vector_store = MilvusVectorStore(
    uri=str(Path(mkdtemp()) / "docling.db"),  # Temporary database
    dim=embed_dim,
    overwrite=True,
)

# Create the index
index = VectorStoreIndex.from_documents(
    documents=reader.load_data(SOURCE),
    transformations=[node_parser],
    storage_context=StorageContext.from_defaults(vector_store=vector_store),
    embed_model=EMBED_MODEL,
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[60], line 20
#      12 vector_store = MilvusVectorStore(
#      13     uri=str(Path(mkdtemp()) / "docling.db"),  # Temporary database
#      14     dim=embed_dim,
#      15     overwrite=True,
#      16 )
#      18 # Create the index
#      19 index = VectorStoreIndex.from_documents(
# ---> 20     documents=reader.load_data(SOURCE),
#      21     transformations=[node_parser],
#      22     storage_context=StorageContext.from_defaults(vector_store=vector_store),
#      23     embed_model=EMBED_MODEL,
#      24 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/llama_index/core/readers/base.py:36, in BaseReader.load_data(self, *args, **load_kwargs)
#      34 def load_data(self, *args: Any, **load_kwargs: Any) -> List[Document]:
#      35     """Load data from the input directory."""
# ---> 36     return list(self.lazy_load_data(*args, **load_kwargs))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/llama_index/readers/docling/base.py:65, in DoclingReader.lazy_load_data(self, file_path, extra_info)
#      58 file_paths = (
#      59     file_path
#      60     if isinstance(file_path, Iterable) and not isinstance(file_path, str)
#      61     else [file_path]
#      62 )
#      64 for source in file_paths:
# ---> 65     dl_doc = self.doc_converter.convert(source).document
#      66     text: str
#      67     if self.export_type == self.ExportType.MARKDOWN:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pydantic/_internal/_validate_call.py:38, in update_wrapper_attributes.<locals>.wrapper_function(*args, **kwargs)
#      36 @functools.wraps(wrapped)
#      37 def wrapper_function(*args, **kwargs):
# ---> 38     return wrapper(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pydantic/_internal/_validate_call.py:111, in ValidateCallWrapper.__call__(self, *args, **kwargs)
#     110 def __call__(self, *args: Any, **kwargs: Any) -> Any:
# --> 111     res = self.__pydantic_validator__.validate_python(pydantic_core.ArgsKwargs(args, kwargs))
#     112     if self.__return_pydantic_validator__:
#     113         return self.__return_pydantic_validator__(res)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/docling/document_converter.py:172, in DocumentConverter.convert(self, source, raises_on_error, max_num_pages, max_file_size)
#     157 @validate_call(config=ConfigDict(strict=True))
#     158 def convert(
#     159     self,
#    (...)
#     163     max_file_size: int = sys.maxsize,
#     164 ) -> ConversionResult:
#     166     all_res = self.convert_all(
#     167         source=[source],
#     168         raises_on_error=raises_on_error,
#     169         max_num_pages=max_num_pages,
#     170         max_file_size=max_file_size,
#     171     )
# --> 172     return next(all_res)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/docling/document_converter.py:193, in DocumentConverter.convert_all(self, source, raises_on_error, max_num_pages, max_file_size)
#     190 conv_res_iter = self._convert(conv_input, raises_on_error=raises_on_error)
#     192 had_result = False
# --> 193 for conv_res in conv_res_iter:
#     194     had_result = True
#     195     if raises_on_error and conv_res.status not in {
#     196         ConversionStatus.SUCCESS,
#     197         ConversionStatus.PARTIAL_SUCCESS,
#     198     }:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/docling/document_converter.py:228, in DocumentConverter._convert(self, conv_input, raises_on_error)
#     219 _log.info(f"Going to convert document batch...")
#     221 # parallel processing only within input_batch
#     222 # with ThreadPoolExecutor(
#     223 #    max_workers=settings.perf.doc_batch_concurrency
#     224 # ) as pool:
#     225 #   yield from pool.map(self.process_document, input_batch)
#     226 # Note: PDF backends are not thread-safe, thread pool usage was disabled.
# --> 228 for item in map(
#     229     partial(self._process_document, raises_on_error=raises_on_error),
#     230     input_batch,
#     231 ):
#     232     elapsed = time.monotonic() - start_time
#     233     start_time = time.monotonic()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/docling/document_converter.py:269, in DocumentConverter._process_document(self, in_doc, raises_on_error)
#     265 valid = (
#     266     self.allowed_formats is not None and in_doc.format in self.allowed_formats
#     267 )
#     268 if valid:
# --> 269     conv_res = self._execute_pipeline(in_doc, raises_on_error=raises_on_error)
#     270 else:
#     271     error_message = f"File format not allowed: {in_doc.file}"
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/docling/document_converter.py:292, in DocumentConverter._execute_pipeline(self, in_doc, raises_on_error)
#     290 pipeline = self._get_pipeline(in_doc.format)
#     291 if pipeline is not None:
# --> 292     conv_res = pipeline.execute(in_doc, raises_on_error=raises_on_error)
#     293 else:
#     294     if raises_on_error:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/docling/pipeline/base_pipeline.py:44, in BasePipeline.execute(self, in_doc, raises_on_error)
#      38 try:
#      39     with TimeRecorder(
#      40         conv_res, "pipeline_total", scope=ProfilingScope.DOCUMENT
#      41     ):
#      42         # These steps are building and assembling the structure of the
#      43         # output DoclingDocument
# ---> 44         conv_res = self._build_document(conv_res)
#      45         conv_res = self._assemble_document(conv_res)
#      46         # From this stage, all operations should rely only on conv_res.output
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/docling/pipeline/base_pipeline.py:149, in PaginatedPipeline._build_document(self, conv_res)
#     146 # 2. Run pipeline stages
#     147 pipeline_pages = self._apply_on_pages(conv_res, init_pages)
# --> 149 for p in pipeline_pages:  # Must exhaust!
#     150     pass
#     152 end_pb_time = time.time() - start_pb_time
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/docling/pipeline/base_pipeline.py:116, in PaginatedPipeline._apply_on_pages(self, conv_res, page_batch)
#     113 for model in self.build_pipe:
#     114     page_batch = model(conv_res, page_batch)
# --> 116 yield from page_batch
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/docling/models/page_assemble_model.py:59, in PageAssembleModel.__call__(self, conv_res, page_batch)
#      56 def __call__(
#      57     self, conv_res: ConversionResult, page_batch: Iterable[Page]
#      58 ) -> Iterable[Page]:
# ---> 59     for page in page_batch:
#      60         assert page._backend is not None
#      61         if not page._backend.is_valid():
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/docling/models/table_structure_model.py:93, in TableStructureModel.__call__(self, conv_res, page_batch)
#      90     yield from page_batch
#      91     return
# ---> 93 for page in page_batch:
#      94     assert page._backend is not None
#      95     if not page._backend.is_valid():
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/docling/models/layout_model.py:281, in LayoutModel.__call__(self, conv_res, page_batch)
#     277 def __call__(
#     278     self, conv_res: ConversionResult, page_batch: Iterable[Page]
#     279 ) -> Iterable[Page]:
# --> 281     for page in page_batch:
#     282         assert page._backend is not None
#     283         if not page._backend.is_valid():
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/docling/models/easyocr_model.py:67, in EasyOcrModel.__call__(self, conv_res, page_batch)
#      63 high_res_image = page._backend.get_page_image(
#      64     scale=self.scale, cropbox=ocr_rect
#      65 )
#      66 im = numpy.array(high_res_image)
# ---> 67 result = self.reader.readtext(im)
#      69 del high_res_image
#      70 del im
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/easyocr/easyocr.py:468, in Reader.readtext(self, image, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, min_size, contrast_ths, adjust_contrast, filter_ths, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, y_ths, x_ths, add_margin, threshold, bbox_min_score, bbox_min_size, max_candidates, output_format)
#     466 # get the 1st result from hor & free list as self.detect returns a list of depth 3
#     467 horizontal_list, free_list = horizontal_list[0], free_list[0]
# --> 468 result = self.recognize(img_cv_grey, horizontal_list, free_list,\
#     469                         decoder, beamWidth, batch_size,\
#     470                         workers, allowlist, blocklist, detail, rotation_info,\
#     471                         paragraph, contrast_ths, adjust_contrast,\
#     472                         filter_ths, y_ths, x_ths, False, output_format)
#     474 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/easyocr/easyocr.py:384, in Reader.recognize(self, img_cv_grey, horizontal_list, free_list, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, contrast_ths, adjust_contrast, filter_ths, y_ths, x_ths, reformat, output_format)
#     382     f_list = []
#     383     image_list, max_width = get_image_list(h_list, f_list, img_cv_grey, model_height = imgH)
# --> 384     result0 = get_text(self.character, imgH, int(max_width), self.recognizer, self.converter, image_list,\
#     385                   ignore_char, decoder, beamWidth, batch_size, contrast_ths, adjust_contrast, filter_ths,\
#     386                   workers, self.device)
#     387     result += result0
#     388 for bbox in free_list:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/easyocr/recognition.py:206, in get_text(character, imgH, imgW, recognizer, converter, image_list, ignore_char, decoder, beamWidth, batch_size, contrast_ths, adjust_contrast, filter_ths, workers, device)
#     201 test_loader = torch.utils.data.DataLoader(
#     202     test_data, batch_size=batch_size, shuffle=False,
#     203     num_workers=int(workers), collate_fn=AlignCollate_normal, pin_memory=True)
#     205 # predict first round
# --> 206 result1 = recognizer_predict(recognizer, converter, test_loader,batch_max_length,\
#     207                              ignore_idx, char_group_idx, decoder, beamWidth, device = device)
#     209 # predict second round
#     210 low_confident_idx = [i for i,item in enumerate(result1) if (item[1] < contrast_ths)]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/easyocr/recognition.py:106, in recognizer_predict(model, converter, test_loader, batch_max_length, ignore_idx, char_group_idx, decoder, beamWidth, device)
#     104 for image_tensors in test_loader:
#     105     batch_size = image_tensors.size(0)
# --> 106     image = image_tensors.to(device)
#     107     # For max length prediction
#     108     length_for_pred = torch.IntTensor([batch_max_length] * batch_size).to(device)
#
# KeyboardInterrupt:

# %%
# Query the pipeline
result = index.as_query_engine(llm=GEN_MODEL).query(QUERY)

# Display the results
print(f"Q: {QUERY}\nA: {result.response.strip()}\n\nSources:")
for node in result.source_nodes:
    print(f"Text: {node.text}\nMetadata: {node.metadata}\n")
